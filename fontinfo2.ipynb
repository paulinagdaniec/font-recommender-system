# %%
import json
from collections import defaultdict

import pandas as pd
import streamlit

# %%
df = pd.read_csv("avfonts.csv")

# %%
df.head()
# Out:
#          family    Category  rating            id  \
# 0        Roboto  sans-serif       1        roboto
# 1     Open Sans  sans-serif       2     open-sans
# 2  Noto Sans JP  sans-serif       3  noto-sans-jp
# 3    Montserrat  sans-serif       4    montserrat
# 4          Lato  sans-serif       5          lato
#
#                                weights                styles  \
# 0              100,300,400,500,700,900  ['italic', 'normal']
# 1              300,400,500,600,700,800  ['italic', 'normal']
# 2              100,300,400,500,700,900            ['normal']
# 3  100,200,300,400,500,600,700,800,900  ['italic', 'normal']
# 4                  100,300,400,700,900  ['italic', 'normal']
#
#                                         connotations   character  \
# 0  modern, clean, universal, open, informal, prog...  character1
# 1  modern, clean, universal, open, informal, prog...  character1
# 2  modern, clean, universal, open, informal, prog...  character1
# 3  modern, clean, universal, open, informal, prog...  character1
# 4  modern, clean, universal, open, informal, prog...  character1
#
#                                      available_fonts
# 0  Roboto-Medium,Roboto-Light,RobotoMono,RobotoSl...
# 1  OpenSansHebrewCondensed-Italic,OpenSansHebrew-...
# 2                                         NotoSansJP
# 3  MontserratAlternates-Thin,MontserratAlternates...
# 4  Lato-Italic,Lato-LightItalic,Lato-Thin,Lato-Bo...

# %%
df["fam_lower"] = df["family"].str.lower().str.replace(" ", "")

# %%
years = pd.read_csv("years.csv", dtype={"Family": str, "Year": int})

# %%
years.rename(columns={"Family": "fam_lower"}, inplace=True)

# %%
wy = df.join(years.set_index("fam_lower"), on="fam_lower")
wy["year"].fillna(2023, inplace=True)

# %%
kw = pd.read_csv("keywordsfiltered.csv", dtype={"keyword": str, "count": int})

# %%
kw
# Out:
#            keyword  count
# 0           modern    347
# 1           global    210
# 2        available    198
# 3      unmodulated    165
# 4          regular    149
# ..             ...    ...
# 113        chinese     11
# 114         famous     11
# 115     impossible     11
# 116  sophisticated     11
# 117      whimsical     11
#
# [118 rows x 2 columns]

# %%
descs = pd.read_csv("descriptions.csv", dtype={"font": str, "description": str})

# %%
descs.rename(columns={"font": "fam_lower"}, inplace=True)

# %%
wyd = wy.join(descs.set_index("fam_lower"), on="fam_lower")
wyd["description"].fillna("", inplace=True)

# %%
def get_keywords(desc):
    return set(kw for kw in kw["keyword"] if kw in desc)

# %%
wyd["keywords"] = wyd["description"].apply(get_keywords)

# %%
designers = pd.read_csv("designers.csv", dtype={"designer": str, "font": str})

# %%
designers = designers.groupby("font").aggregate(lambda x: list(x))

# %%
designers.rename(columns={"font": "fam_lower"}, inplace=True)

# %%
wydk = wyd.join(designers, on="fam_lower")

# %%
wydk
# Out:
#                     family    Category  rating                    id  \
# 0                   Roboto  sans-serif       1                roboto
# 1                Open Sans  sans-serif       2             open-sans
# 2             Noto Sans JP  sans-serif       3          noto-sans-jp
# 3               Montserrat  sans-serif       4            montserrat
# 4                     Lato  sans-serif       5                  lato
# ...                    ...         ...     ...                   ...
# 1447   Noto Sans Nabataean  sans-serif    1491   noto-sans-nabataean
# 1448     Noto Sans Sogdian  sans-serif    1492     noto-sans-sogdian
# 1449  Noto Sans Old Permic  sans-serif    1493  noto-sans-old-permic
# 1450    Noto Sans Mahajani  sans-serif    1494    noto-sans-mahajani
# 1451       Noto Sans Nushu  sans-serif    1495       noto-sans-nushu
#
#                                   weights                styles  \
# 0                 100,300,400,500,700,900  ['italic', 'normal']
# 1                 300,400,500,600,700,800  ['italic', 'normal']
# 2                 100,300,400,500,700,900            ['normal']
# 3     100,200,300,400,500,600,700,800,900  ['italic', 'normal']
# 4                     100,300,400,700,900  ['italic', 'normal']
# ...                                   ...                   ...
# 1447                                  400            ['normal']
# 1448                                  400            ['normal']
# 1449                                  400            ['normal']
# 1450                                  400            ['normal']
# 1451                                  400            ['normal']
#
#                                            connotations   character  \
# 0     modern, clean, universal, open, informal, prog...  character1
# 1     modern, clean, universal, open, informal, prog...  character1
# 2     modern, clean, universal, open, informal, prog...  character1
# 3     modern, clean, universal, open, informal, prog...  character1
# 4     modern, clean, universal, open, informal, prog...  character1
# ...                                                 ...         ...
# 1447  modern, clean, universal, open, informal, prog...  character1
# 1448  modern, clean, universal, open, informal, prog...  character1
# 1449  modern, clean, universal, open, informal, prog...  character1
# 1450  modern, clean, universal, open, informal, prog...  character1
# 1451  modern, clean, universal, open, informal, prog...  character1
#
#                                         available_fonts          fam_lower  \
# 0     Roboto-Medium,Roboto-Light,RobotoMono,RobotoSl...             roboto
# 1     OpenSansHebrewCondensed-Italic,OpenSansHebrew-...           opensans
# 2                                            NotoSansJP         notosansjp
# 3     MontserratAlternates-Thin,MontserratAlternates...         montserrat
# 4     Lato-Italic,Lato-LightItalic,Lato-Thin,Lato-Bo...               lato
# ...                                                 ...                ...
# 1447                          NotoSansNabataean-Regular  notosansnabataean
# 1448                            NotoSansSogdian-Regular    notosanssogdian
# 1449                          NotoSansOldPermic-Regular  notosansoldpermic
# 1450                           NotoSansMahajani-Regular   notosansmahajani
# 1451                              NotoSansNushu-Regular      notosansnushu
#
#         year                                        description  \
# 0     2011.0  \nRoboto has a dual nature. \nIt has a mechani...
# 1     2020.0  \nOpen Sans is a humanist sans serif typeface ...
# 2     2021.0  \n  Noto is a global font collection for writi...
# 3     2011.0  \nThe old posters and signs in the traditional...
# 4     2015.0  \nLato means “Summer” in Polish, and it is a s...
# ...      ...                                                ...
# 1447  2018.0  \n  Noto is a global font collection for writi...
# 1448  2019.0  \n  Noto is a global font collection for writi...
# 1449  2017.0  \n  Noto is a global font collection for writi...
# 1450  2018.0  \n  Noto is a global font collection for writi...
# 1451  2020.0  \n  Noto is a global font collection for writi...
#
#                                                keywords  \
# 0     {different, natural, mechanical, variable, com...
# 1     {upright, neutral, characteristic, variable, c...
# 2                         {global, unmodulated, modern}
# 3              {normal, original, special, traditional}
# 4     {different, particular, corporate, original, l...
# ...                                                 ...
# 1447          {historical, global, unmodulated, modern}
# 1448          {historical, global, unmodulated, modern}
# 1449          {historical, global, unmodulated, modern}
# 1450          {historical, global, unmodulated, modern}
# 1451  {smaller, global, modern, special, unmodulated...
#
#                                                designer
# 0          [Christian Robertson, Paratype, Font Bureau]
# 1                                      [Steve Matteson]
# 2                                              [Google]
# 3     [Julieta Ulanovsky, Sol Matas, Juan Pablo del ...
# 4                                     [Łukasz Dziedzic]
# ...                                                 ...
# 1447                                           [Google]
# 1448                                           [Google]
# 1449                                           [Google]
# 1450                                           [Google]
# 1451                                           [Google]
#
# [1452 rows x 14 columns]

# %%
wydk.columns
# Out:
# Index(['family', 'Category', 'rating', 'id', 'weights', 'styles',
#        'connotations', 'character', 'available_fonts', 'fam_lower', 'year',
#        'description', 'keywords', 'designer'],
#       dtype='object')

# %%
wydk.to_csv("avfonts_full.csv", index=False)

# %%
df = pd.read_csv("avfonts_full.csv")

def parse_designer(designer):
    try:
        return json.loads(designer.replace("'", '"'))
    except:
        return None

replace = str.maketrans("", "", "{}'")
df["keywords"] = df["keywords"].apply(lambda x: set(x.translate(replace).split(", ")))
df["weights"] = df["weights"].apply(lambda x: x.split(","))
df["styles"] = df["styles"].apply(lambda x: json.loads(x.replace("'", '"')))
df["connotations"] = df["connotations"].apply(lambda x: x.split(", "))
df["designer"] = df["designer"].astype(str).apply(parse_designer)

# %%
liked = df[df["family"].str.contains("obo")]
disliked = df[df["family"].str.contains("ono")]

# %%
def rate_fonts(df, liked, disliked):
    keyword_ratings_factor = 10
    designer_ratings_factor = 1
    connotation_ratings_factor = 0.5
    year_factor = 0.1

    keyword_ratings = defaultdict(int)
    for entry in liked["keywords"]:
        for kw in entry:
            keyword_ratings[kw] += 1

    for entry in disliked["keywords"]:
        for kw in entry:
            keyword_ratings[kw] -= 1

    designer_ratings = defaultdict(int)
    for entry in liked["designer"]:
        if entry is None:
            continue
        for d in entry:
            designer_ratings[d] += 1

    for entry in disliked["designer"]:
        if entry is None:
            continue
        for d in entry:
            designer_ratings[d] -= 1

    connotation_ratings = defaultdict(int)
    for entry in liked["connotations"]:
        for c in entry:
            connotation_ratings[c] += 1

    for entry in disliked["connotations"]:
        for c in entry:
            connotation_ratings[c] -= 1

    liked_year_avg = liked["year"].mean()
    disliked_year_avg = disliked["year"].mean()
    middle_year = (liked_year_avg + disliked_year_avg) / 2

    def rate_font(row):
        rating = 0
        for kw in row["keywords"]:
            rating += keyword_ratings[kw] * keyword_ratings_factor
        for d in row["designer"] if row["designer"] is not None else []:
            rating += designer_ratings[d] * designer_ratings_factor
        for c in row["connotations"]:
            rating += connotation_ratings[c] * connotation_ratings_factor

        rating += (row["year"] - middle_year) * year_factor

        rating -= row["rating"] / 1000
        return rating

    df["rating"] = df.apply(rate_font, axis=1)

    return df.sort_values("rating", ascending=False)

r = rate_fonts(df, liked, disliked)

# Remove elements of r that are already in liked or disliked
r = r[~r["family"].isin(liked["family"])]
r = r[~r["family"].isin(disliked["family"])]

# %%
# Load ratings from the CSV file
user_input = pd.read_csv("user_input.csv")
liked = user_input[user_input[" Liked"] == "True"][" Selected Font"].str.replace(".ttf", "")
disliked = user_input[user_input[" Disliked"] == "True"][" Selected Font"].str.replace(".ttf", "")

liked_entries = pd.DataFrame(columns=df.columns)
for font in liked:
    liked_entries = liked_entries.append(df.loc[df["available_fonts"].str.contains(font)])

disliked_entrie = pd.DataFrame(columns=df.columns)
for font in disliked:
    disliked = disliked.append(df.loc[df["available_fonts"].str.contains(font)])
# Out:
# /tmp/ipykernel_54531/3889668018.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   liked = user_input[user_input[" Liked"] == "True"][" Selected Font"].str.replace(".ttf", "")
# /tmp/ipykernel_54531/3889668018.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   disliked = user_input[user_input[" Disliked"] == "True"][" Selected Font"].str.replace(".ttf", "")
# /tmp/ipykernel_54531/3889668018.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liked_entries = liked_entries.append(df.loc[df["available_fonts"].str.contains(font)])
# /tmp/ipykernel_54531/3889668018.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liked_entries = liked_entries.append(df.loc[df["available_fonts"].str.contains(font)])
# /tmp/ipykernel_54531/3889668018.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liked_entries = liked_entries.append(df.loc[df["available_fonts"].str.contains(font)])
# /tmp/ipykernel_54531/3889668018.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liked_entries = liked_entries.append(df.loc[df["available_fonts"].str.contains(font)])
# /tmp/ipykernel_54531/3889668018.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liked_entries = liked_entries.append(df.loc[df["available_fonts"].str.contains(font)])
# /tmp/ipykernel_54531/3889668018.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liked_entries = liked_entries.append(df.loc[df["available_fonts"].str.contains(font)])
# /tmp/ipykernel_54531/3889668018.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liked_entries = liked_entries.append(df.loc[df["available_fonts"].str.contains(font)])
# /tmp/ipykernel_54531/3889668018.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liked_entries = liked_entries.append(df.loc[df["available_fonts"].str.contains(font)])
# /tmp/ipykernel_54531/3889668018.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liked_entries = liked_entries.append(df.loc[df["available_fonts"].str.contains(font)])
# /tmp/ipykernel_54531/3889668018.py:12: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   disliked = disliked.append(df.loc[df["available_fonts"].str.contains(font)])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[191], line 12
#      10 disliked_entrie = pd.DataFrame(columns=df.columns)
#      11 for font in disliked:
# ---> 12     disliked = disliked.append(df.loc[df["available_fonts"].str.contains(font)])
#
# File ~/Projects/State of the art - codes and data/venv/lib/python3.10/site-packages/pandas/core/series.py:3140, in Series.append(self, to_append, ignore_index, verify_integrity)
#    3059 """
#    3060 Concatenate two or more Series.
#    3061
#    (...)
#    3130 ValueError: Indexes have overlapping values: [0, 1, 2]
#    3131 """
#    3132 warnings.warn(
#    3133     "The series.append method is deprecated "
#    3134     "and will be removed from pandas in a future version. "
#    (...)
#    3137     stacklevel=find_stack_level(),
#    3138 )
# -> 3140 return self._append(to_append, ignore_index, verify_integrity)
#
# File ~/Projects/State of the art - codes and data/venv/lib/python3.10/site-packages/pandas/core/series.py:3154, in Series._append(self, to_append, ignore_index, verify_integrity)
#    3152 if any(isinstance(x, (ABCDataFrame,)) for x in to_concat[1:]):
#    3153     msg = "to_append should be a Series or list/tuple of Series, got DataFrame"
# -> 3154     raise TypeError(msg)
#    3155 return concat(
#    3156     to_concat, ignore_index=ignore_index, verify_integrity=verify_integrity
#    3157 )
#
# TypeError: to_append should be a Series or list/tuple of Series, got DataFrame

# %%
# Out:
# LovedbytheKing
# Inder-Regular
# Armata-Regular
# Georama
# Cantarell-Bold
# NotoSansOldPermic-Regular
# NotoSansSinhala
# ExpletusSans-Italic
# Galada-Regular
# /tmp/ipykernel_54531/3552148410.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   loved = loved.append(df.loc[df["available_fonts"].str.contains(font)])
# /tmp/ipykernel_54531/3552148410.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   loved = loved.append(df.loc[df["available_fonts"].str.contains(font)])
# /tmp/ipykernel_54531/3552148410.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   loved = loved.append(df.loc[df["available_fonts"].str.contains(font)])
# /tmp/ipykernel_54531/3552148410.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   loved = loved.append(df.loc[df["available_fonts"].str.contains(font)])
# /tmp/ipykernel_54531/3552148410.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   loved = loved.append(df.loc[df["available_fonts"].str.contains(font)])
# /tmp/ipykernel_54531/3552148410.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   loved = loved.append(df.loc[df["available_fonts"].str.contains(font)])
# /tmp/ipykernel_54531/3552148410.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   loved = loved.append(df.loc[df["available_fonts"].str.contains(font)])
# /tmp/ipykernel_54531/3552148410.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   loved = loved.append(df.loc[df["available_fonts"].str.contains(font)])
# /tmp/ipykernel_54531/3552148410.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   loved = loved.append(df.loc[df["available_fonts"].str.contains(font)])

# %%
liked_entries
# Out:
#                     family     Category      rating                    id  \
# 814      Loved by the King  handwriting   -2.096714     loved-by-the-king
# 627                  Inder   sans-serif  -11.687143                 inder
# 349                 Armata   sans-serif  -91.407423                armata
# 443                Georama   sans-serif  -50.648182               georama
# 660                    Geo   sans-serif  -41.657173                   geo
# 196              Cantarell   sans-serif  -61.737093             cantarell
# 12               Noto Sans   sans-serif -111.487343             noto-sans
# 1449  Noto Sans Old Permic   sans-serif  -51.946884  noto-sans-old-permic
# 12               Noto Sans   sans-serif -111.487343             noto-sans
# 697      Noto Sans Sinhala   sans-serif  -51.447383     noto-sans-sinhala
# 692          Expletus Sans      display    2.198983         expletus-sans
# 578                 Galada      display   -8.190627                galada
#
#                                             weights            styles  \
# 814                                           [400]          [normal]
# 627                                           [400]          [normal]
# 349                                           [400]          [normal]
# 443   [100, 200, 300, 400, 500, 600, 700, 800, 900]  [italic, normal]
# 660                                           [400]  [italic, normal]
# 196                                      [400, 700]  [italic, normal]
# 12    [100, 200, 300, 400, 500, 600, 700, 800, 900]  [italic, normal]
# 1449                                          [400]          [normal]
# 12    [100, 200, 300, 400, 500, 600, 700, 800, 900]  [italic, normal]
# 697   [100, 200, 300, 400, 500, 600, 700, 800, 900]          [normal]
# 692                            [400, 500, 600, 700]  [italic, normal]
# 578                                           [400]          [normal]
#
#                                            connotations   character  \
# 814   [personal, friendly, whimsical, casual, expres...  character4
# 627   [modern, clean, universal, open, informal, pro...  character1
# 349   [modern, clean, universal, open, informal, pro...  character1
# 443   [modern, clean, universal, open, informal, pro...  character1
# 660   [modern, clean, universal, open, informal, pro...  character1
# 196   [modern, clean, universal, open, informal, pro...  character1
# 12    [modern, clean, universal, open, informal, pro...  character1
# 1449  [modern, clean, universal, open, informal, pro...  character1
# 12    [modern, clean, universal, open, informal, pro...  character1
# 697   [modern, clean, universal, open, informal, pro...  character1
# 692   [creative, eye-catching, decorative, bold, pla...  character2
# 578   [creative, eye-catching, decorative, bold, pla...  character2
#
#                                         available_fonts          fam_lower  \
# 814                                      LovedbytheKing     lovedbytheking
# 627                                       Inder-Regular              inder
# 349                                      Armata-Regular             armata
# 443                              Georama,Georama-Italic            georama
# 660   NotoSansGeorgian,GeostarFill-Regular,Geo-Regul...                geo
# 196   Cantarell-Bold,Cantarell-BoldItalic,Cantarell-...          cantarell
# 12    NotoSansLepcha-Regular,NotoSansThaana,NotoSans...           notosans
# 1449                          NotoSansOldPermic-Regular  notosansoldpermic
# 12    NotoSansLepcha-Regular,NotoSansThaana,NotoSans...           notosans
# 697                   NotoSansSinhala,NotoSansSinhalaUI    notosanssinhala
# 692                    ExpletusSans-Italic,ExpletusSans       expletussans
# 578                                      Galada-Regular             galada
#
#         year                                        description  \
# 814   2006.0  A skinny font that fits in little places. This...
# 627   2010.0  Foundry: Sorkin Type Co\nInder is a low contra...
# 349   2012.0  \nArmata is a low contrast sans serif text fac...
# 443   2020.0  Georama is an original typeface available in s...
# 660   2010.0  I was shown squared-off lettering on a record ...
# 196   2009.0  The Cantarell typeface family was designed dur...
# 12    2021.0  \n  Noto is a global font collection for writi...
# 1449  2017.0  \n  Noto is a global font collection for writi...
# 12    2021.0  \n  Noto is a global font collection for writi...
# 697   2022.0  \n  Noto is a global font collection for writi...
# 692   2019.0  \n    Expletus Sans is a display typeface, whi...
# 578   2015.0  \nGalada is a Bengali and Latin font that star...
#
#                                                keywords               designer
# 814                                            {little}     [Kimberly Geswein]
# 627                                         {available}          [Sorkin Type]
# 349                                             {set()}  [Viktoriya Grabowska]
# 443                      {original, several, available}      [Production Type]
# 660                 {strong, similar, modern, complete}           [Ben Weiner]
# 196                          {particular, contemporary}       [Dave Crossland]
# 12    {global, modern, specific, unmodulated, suitable}               [Google]
# 1449          {global, unmodulated, historical, modern}               [Google]
# 12    {global, modern, specific, unmodulated, suitable}               [Google]
# 697                       {global, unmodulated, modern}               [Google]
# 692                                {variable, upgraded}           [Designtown]
# 578                                            {famous}        [Black Foundry]

# %%
liked
# Out:
# 11               LovedbytheKing
# 14                Inder-Regular
# 16               Armata-Regular
# 19                      Georama
# 22               Cantarell-Bold
# 25    NotoSansOldPermic-Regular
# 26              NotoSansSinhala
# 27          ExpletusSans-Italic
# 30               Galada-Regular
# Name:  Selected Font, dtype: object
